# %% [markdown]
# ### Imports

# %%
import pandas as pd
import requests
import json
import concurrent.futures
from bs4 import BeautifulSoup

from helpers.readers import read_dataframe

# %% [markdown]
# ### Loading CMU movies

# %%
cmu_movies = read_dataframe(name='cmu/movies', preprocess=True, usecols=[
    "Wikipedia movie ID", 
    "Freebase movie ID", 
    "Movie name", 
    "Movie release date", 
    "Movie box office revenue", 
    "Movie runtime", 
    "Movie languages", 
    "Movie countries", 
    "Movie genres",
])
# Out:
# Preprocess logs:
# ✅ Fixed Movie Languages inside Movie Countries
# ✅ Removed Deseret characters
# ✅ Movie release date splitted to three columns: Movie release Year, Movie release Month, Movie release Day
# ✅ Seperated freebase identifiers from Movie Languages, Movie Countries and Movie Genres
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81741 entries, 0 to 81740
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Wikipedia movie ID        81741 non-null  int32
#  1   Freebase movie ID         81741 non-null  string
#  2   Movie name                81741 non-null  string
#  3   Movie box office revenue  8401 non-null   float64
#  4   Movie runtime             61291 non-null  float32
#  5   Movie release Year        74839 non-null  Int16
#  6   Movie release Month       42667 non-null  Int8
#  7   Movie release Day         39373 non-null  Int8
#  8   Movie languages           81741 non-null  string
#  9   Movie countries           81741 non-null  string
#  10  Movie genres              81741 non-null  string
# dtypes: Int16(1), Int8(2), float32(1), float64(1), int32(1), string(5)
# memory usage: 4.9 MB
#    Wikipedia movie ID Freebase movie ID      Movie name  \
# 0              975900         /m/03vyhn  Ghosts of Mars
#
#    Movie box office revenue  Movie runtime  Movie release Year  \
# 0                14010832.0           98.0                2001
#
#    Movie release Month  Movie release Day Movie languages  \
# 0                    8                 24         English
#
#             Movie countries                                       Movie genres
# 0  United States of America  Thriller,Science Fiction,Horror,Adventure,Supe...

# %% [markdown]
# ### Scraping wikipedia infobox
#
# ![](https://iili.io/Jzt025J.png)

# %% [markdown]
# Two weaknesses:
# - Uses the english version of wikipedia, non english or less popular movies may not have an english webpage
# - Less popular movies don't have an infobox

# %%
def scrape_infobox(wiki_movie_id):
    url = f"https://en.wikipedia.org/?curid={wiki_movie_id}"
    response = requests.get(url)
    infobox_data = {}

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        infobox = soup.find('table', {'class': 'infobox'})

        if infobox:
            rows = infobox.find_all('tr')
            for row in rows:
                header = row.find('th')
                if header:
                    header_text = header.text.strip()
                    value = row.find('td')
                    if value:
                        # Some values might have references/citations, which you might want to remove
                        for sup in value.find_all('sup'):
                            sup.decompose()
                        infobox_data[header_text] = value.get_text(separator=" ", strip=True)

    return infobox_data

# %%
def save_results(results, filename):
    with open(filename, 'w') as f:
        json.dump(results, f)

# %%
def process_movie_id(wiki_id):
    try:
        movie_infobox = scrape_infobox(wiki_id)
        return wiki_id, movie_infobox
    except Exception as e:
        print(f"Error processing {wiki_id}: {e}")
        return wiki_id, None

# %%
movie_wiki_ids = cmu_movies["Wikipedia movie ID"].tolist()
results = []
max_workers = 10  # Adjust based on network/environment

with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
    results = list(tqdm(executor.map(process_movie_id, movie_wiki_ids), total=len(movie_wiki_ids)))

save_results(results, 'infobox_results.json')
print("Scraping completed.")
# Out:
#   0%|          | 0/81741 [00:00<?, ?it/s]
# Error processing 3380491: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 27375141: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 28131017: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 14193740: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 31431586: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 4287489: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 13879045: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Error processing 7650972: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing 4494129: ("Connection broken: InvalidChunkLength(got length b'', 0 bytes read)", InvalidChunkLength(got length b'', 0 bytes read))
# Error processing 461364: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Scraping completed.

# %% [markdown]
# ### Checking results

# %%
import json
import pandas as pd

with open('./generated/infobox_results.json', 'r') as file:
    results = json.load(file)

failed_wiki_ids = [wiki_id for wiki_id, data in results if not data]

print("Failed Wiki IDs:", failed_wiki_ids)
# Out:
# Failed Wiki IDs: [18998739, 9997961, 33427105, 20604092, 31025505, 23799443, 16686643, 19929835, 11717027, 3222645, 32229606, 12142896, 32839744, 30693170, 12491178, 31025540, 18496109, 28327554, 8955475, 22644083, 6792375, 16672517, 33519683, 5771666, 15457461, 30624204, 13931033, 16572418, 33544694, 22757028, 22557257, 28858056, 26726624, 20611297, 9139404, 18848953, 19961614, 4038269, 15890474, 665676, 18900393, 7267251, 30729485, 7458959, 26283021, 2298689, 7280802, 9782958, 20695060, 8088400, 33616397, 18053600, 9993314, 31157561, 9993323, 15753282, 25131827, 7586366, 27044179, 9985468, 36410662, 11921020, 34090675, 23404570, 6109092, 8913767, 34992168, 22644468, 28379587, 9919006, 28492939, 5445021, 34916655, 9919009, 19490946, 6602958, 30531735, 7612646, 28692419, 28379461, 9308502, 34953631, 9879584, 28275468, 967367, 8781041, 28374748, 33551059, 21482599, 36052259, 28492562, 15284386, 27278051, 29510726, 27744173, 24833392, 5922485, 19931996, 6109156, 2267337, 35784403, 6190947, 14814288, 5396029, 28373900, 32547611, 9858029, 33100959, 5820314, 19687519, 17058733, 20518783, 5853629, 24815671, 20562478, 16024478, 8993821, 28857787, 35556959, 6773730, 25573745, 20249573, 20532977, 14358557, 34952523, 6685838, 33628294, 20520779, 32077060, 31176974, 28088331, 18133264, 18393737, 22643472, 7759459, 16188573, 19289655, 20921173, 33002605, 25274949, 3218724, 30149781, 17327462, 19285497, 15058861, 5479460, 36113338, 28846176, 29801891, 14656823, 3767179, 9994317, 22644293, 20782127, 11011632, 35017681, 23856271, 28858020, 34666140, 23288456, 23367560, 20630951, 25905642, 9919880, 32708834, 11262486, 34671186, 24668668, 12048544, 34670927, 8882141, 11341340, 15247226, 6727805, 14168925, 26057163, 35515514, 20862538, 11105496, 3868267, 4144335, 32174575, 28260158, 21613921, 26107196, 28512680, 250718, 4902184, 5517579, 3331330, 32424995, 28467725, 25937937, 33493916, 31538706, 8827292, 28371323, 30241563, 27932113, 31316750, 9960936, 22644307, 23820585, 17278628, 28379602, 9428128, 19919089, 27822957, 619956, 31168071, 35004777, 31874799, 19288479, 3996989, 28148651, 4633393, 17792184, 16870441, 12093161, 23266599, 10200181, 29288150, 21312593, 17640868, 9056479, 33673220, 31938531, 5082327, 29128683, 26354688, 10056476, 9398262, 26250473, 32170594, 34821308, 11492971, 28492514, 11063028, 28000552, 25745431, 22712088, 2223377, 32529040, 18555435, 24007634, 14760799, 31362067, 16639345, 26958289, 6694349, 12790942, 5434425, 28467381, 29053990, 25183068, 18832680, 10069437, 8484968, 11007979, 6020621, 24169251, 35195870, 13206489, 5121921, 19440246, 3274890, 74937, 13889977, 34771527, 4634549, 9552051, 8796916, 26483776, 20675156, 349715, 7714332, 31156983, 76398, 21824346, 21875134, 25011283, 5863048, 7307622, 11142170, 16049363, 6420587, 32802489, 28378098, 7514871, 28149692, 18357589, 13580430, 23201532, 28090637, 21450003, 31025879, 28373983, 6402018, 1288086, 6285672, 8271137, 23666936, 28492694, 28492960, 11111612, 19163173, 10791833, 28467145, 2396366, 19311559, 28371347, 31849762, 3162235, 32755363, 15406605, 28492684, 33514552, 5655933, 7230428, 31782691, 10988261, 27941379, 31025836, 1702976, 1290887, 28382586, 18540622, 33175021, 3052480, 28766998, 5479920, 9935760, 12811780, 26340376, 5464450, 3826058, 28492592, 18459038, 31739529, 24162430, 8146401, 12246660, 21536219, 25670405, 20632666, 15669310, 11081810, 32145013, 15424259, 33951053, 6774987, 21534991, 5938502, 27763577, 31025611, 34082375, 6970711, 28444123, 33509112, 32598242, 33779630, 32068285, 9339327, 9902001, 27042389, 6100448, 36557164, 36190244, 32210215, 30404263, 19457131, 32170666, 4391220, 5546896, 31025790, 2163880, 3845803, 28291857, 24019653, 20635693, 7079954, 31025852, 31156975, 15546456, 6942353, 5867277, 28725922, 12874575, 28354779, 33778232, 36161222, 3305827, 28517690, 6598746, 6943602, 345281, 9218462, 8419674, 18832919, 3622109, 32267636, 8921364, 27624482, 8549370, 31805047, 28467668, 23791501, 6321263, 17708660, 35004748, 15752561, 20 ...

# %%
len(failed_wiki_ids)
# Out:
# 6584

# %%
unique_keys = set()
for _, infobox in results:
    if infobox:
        unique_keys.update(infobox.keys())

print("Unique Keys:", unique_keys)
# Out:
# Unique Keys: {'Albanian', 'Tax ID no.', 'Subsidiaries', 'Music', 'Cause of death', 'Former names', 'Debut', "Chosŏn'gŭl", 'Launch date', 'Release date', 'Japanese', 'Followed by', 'Language', 'Education', 'Brands', 'Play(s)', 'Commercial', 'Samkhya', 'Editing by', 'Adaptation by', 'Class', 'Begins', 'TV adaptations', 'Programmer(s)', 'Position(s)', 'Unit', 'President', 'Buy rate', 'Producer(s)', 'Spanish', 'Born', 'Chinese', 'Text', 'Organization', 'Significant other', 'Elevation', 'Greek', 'Relative(s)', 'Teleplay by', 'Purpose', 'First organized', 'Animationservices', '2001', 'Nation from', 'Director(s)', 'Parent', 'Position:', 'Licensed\xa0from', 'Height:', 'Narration by', 'Relatives', 'Sinhala', 'Origin', 'Partnerships', 'Country\xa0(sports)', 'Hannah Montana tour chronology', 'Label', 'Best Comedy Series', 'Ground', 'Creator(s)', 'Animators', 'Thought sequences dialogue by', 'Italian', 'Other names', 'Activity sectors', 'Format(s)', 'Theme music composer', 'Dialogs, lyrics', 'Event(s)', 'Recording studio', 'Allegiance', 'Duration', 'Other albums', 'Direct-to-video', 'Engine', 'Type of site', 'Vice-President and Deputy General Secretary', 'Starring', 'Written and directed', 'City', '2012–2013', 'Spouse', 'Radio', 'Nearest\xa0city', '2022–present', 'Channels', 'Plays', 'Executive producer', '2018', 'See also', 'End date', 'Productioncompany', '2012–2015', '2013–2016', 'Service/branch', 'Hangul', 'Alter ego', 'Team affiliations', 'Platform(s)', 'Event', 'Address', 'Sister channels', 'College:', 'Finnish', 'Cinematography', 'Citizenship', 'First mention', 'Bengali', 'Signature', '2017–2022', 'Fate', 'Soundtrack albums', 'Performed', 'Highest\xa0ranking', 'Cinematography by', 'Catalan', 'Hancha', 'Turkish', 'Architectural\xa0style', 'Venue', 'NFL\xa0draft', 'Video games', 'Presented by', '2011–2012', 'Creator', 'Segment producers', 'Attendance', 'Katakana', 'Songwriter(s)', 'Nicknames', 'Listed height', 'Production companies', 'Hosted by', 'Production company', 'Ending theme', 'Equipment', 'Kannada', 'Czech language', 'Referee', 'Receiving yards:', 'NBA draft', 'Total fights', 'Drafted by', 'Sponsor', 'Episode nos.', 'Genre(s)', 'Constituency', 'Occupations', 'Executive producers', 'Original release', 'Icelandic', '1995–1997', 'Past members', 'Genres', '•\xa0Urban[8]', 'Spouses', 'First comic appearance', 'Suggested by', 'ShanghaineseRomanization', 'Location', 'Original text', 'English', 'Sport', 'Arabic', 'Founders', 'Parent(s)', 'First broadcast', 'Body\xa0style', 'Producer', 'Episodes', 'Television series', 'Opening date', 'Replaced', 'Box sets', 'Polish', 'Animation services', 'Web series', 'Video', 'First appearance', 'OCLC', 'Owner', 'Norwegian', '1985–1988', 'Recorded', 'Schedule', 'Alma mater', 'Gujarati', 'Orogeny', 'Picture format', 'Cause\xa0of death', 'Medium', 'Region', 'Years Active', 'Discography', 'Bhutan', 'Chairman', 'Highest governing\xa0body', 'Traditional', 'Alias', 'Inker(s)', 'Associated album', 'Team (Wins)', 'Strokes', 'EPs', 'Age range', 'Related shows', 'Key people', 'Podcast(s)', 'No. of seasons', 'Executive producer(s)', 'Employer', '2007', 'Production location', 'Place premiered', 'Channel', 'Vehicle type', 'Composer', 'Founded', 'Narrated by', 'Head coach', 'Closing date', 'Staff', 'Predecessor', 'Toy(s)', 'Leader of the House', 'Opening theme', 'Best Comedy Performance', 'Home', 'NRHP\xa0reference\xa0No.', 'Music by', 'Burmese', '1989', 'No. of issues', 'Celebrations', 'Secular', 'Broadcast area', 'Magazine', 'CFL\xa0status', 'Editor(s)', 'Television film(s)', 'Weight:', 'Color process', 'Divisions', 'Cover artist', 'Music videos', 'Date', 'US Open', 'Years', 'Traded as', 'Network', 'Comic strip(s)', 'Completed', 'Role-playing', 'College', '2015–2016', 'Position', 'CFL All-Star', 'Ratings', 'Media\xa0type', '•\xa0Urban', 'No. of shows', 'Camera man', 'Related', 'Hebrew', 'Issue', 'Production codes', 'Playing career', 'Founder(s)', 'Vaisheshika', 'Total events', 'Production code', 'Mother', 'List ...

# %% [markdown]
# A lot of unique keys, keep only the useful ones

# %%
# for example the keys from Avengers2012
# https://en.wikipedia.org/wiki/The_Avengers_(2012_film)
desired_keys = [
    'Directed by', 'Screenplay by', 'Story by', 'Based on', 
    'Produced by', 'Starring', 'Cinematography', 'Edited by', 
    'Music by', 'Production company', 'Distributed by', 
    'Release dates', 'Running time', 'Country', 'Language', 
    'Budget', 'Box office'
]

# %%
processed_data = []

for wiki_id, infobox in results:
    if infobox:
        row = [infobox.get(key) for key in desired_keys]
    else:
        row = [None] * len(desired_keys)
    processed_data.append([wiki_id, *row])

column_names = ['Wikipedia movie ID', *desired_keys]

# %%
df = pd.DataFrame(processed_data, columns=column_names)
df.fillna(value=pd.NA, inplace=True)
df
# Out:
#        Wikipedia movie ID                                      Directed by  \
# 0                  975900                                   John Carpenter
# 1                 3196793                                     Edward Lucas
# 2                28463795                                     Sølve Skagen
# 3                 9363483                                   Donald Cammell
# 4                  261236                               Robert van Ackeren
# ...                   ...                                              ...
# 81736            35228177  Sid Bennett Director of Animation - Steve Gomez
# 81737            34980460                                       Ian Palmer
# 81738             9971909                                     Bob Einstein
# 81739              913762                                             <NA>
# 81740            12476867                                    Gavin Wilding
#
#                       Screenplay by                     Story by  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3      Donald Cammell China Cammell                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 81736                          <NA>  Charlie Foley Vaibhav Bhatt
# 81737                          <NA>                         <NA>
# 81738                          <NA>                         <NA>
# 81739                          <NA>                         <NA>
# 81740                          <NA>                         <NA>
#
#                           Based on  \
# 0                             <NA>
# 1                             <NA>
# 2                             <NA>
# 3      Mrs. White by Andrew Klavan
# 4                             <NA>
# ...                            ...
# 81736                         <NA>
# 81737                         <NA>
# 81738                         <NA>
# 81739                         <NA>
# 81740                         <NA>
#
#                                              Produced by  \
# 0                                             Sandy King
# 1                                                   <NA>
# 2                                                   <NA>
# 3      Sue Baden-Powell Cassian Elwes Elliott Kastner...
# 4              Robert van Ackeren Dieter Geissler [ de ]
# ...                                                  ...
# 81736                       Darlow Smithson, Tom Brisley
# 81737                            Teddy Leifer Ian Palmer
# 81738                         Jonathan Haze Tom Smothers
# 81739                                               <NA>
# 81740                                          Mark Reid
#
#                                                 Starring  \
# 0      Ice Cube Natasha Henstridge Jason Statham Pam ...
# 1                                                   <NA>
# 2             Frank Krog Kristin Kajander Anne Krigsvoll
# 3                             David Keith Cathy Moriarty
# 4      Gudrun Landgrebe Mathieu Carrière Hanns Zischl...
# ...                                                  ...
# 81736                                               <NA>
# 81737                                               <NA>
# 81738  Rich Little Herb Voland Bruce Kirby Diahn Will...
# 81739                                               <NA>
# 81740                           Ron Silver Liane Balaban
#
#                  Cinematography           Edited by              Music by  \
# 0                 Gary B. Kibbe  Paul C. Warschilka        John Carpenter
# 1                          <NA>                <NA>                  <NA>
# 2                          <NA>                <NA>                  <NA>
# 3                Larry McConkey      Terry Rawlings  Rick Fenn Nick Mason
# 4                 Jürgen Jürges   Tanja Schmidbauer            Peer Raben
# ...                         ...                 ...                   ...
# 81736                      <NA>                <NA>                  <NA>
# 81737  Michael Doyle Ian Palmer    Ollie Huddleston          Ilan Eshkeri
# 81738                      <NA>                <NA>         Bob Emenegger
# 81739                      <NA>                <NA>                  <NA>
# 81740             Mark Dobrescu          Dean Evans       Chris Ainscough
#
#                 Production company                          Distributed by  \
# 0                             <NA>                 Sony Pictures Releasing
# 1      Rocket Science Laboratories                                    <NA>
# 2                             <NA>                                    <NA>
# 3                             <NA>                            Cannon Films
# 4                             <NA>                                    <NA>
# ...                            ...                                     ...
# 81736                         <NA>  Discovery Communications Animal Planet
# 81737                         <NA>                                    <NA>
# 81738                         <NA>                              Fine Films
# 81739                         <NA>                                    <NA>
# 81740                         <NA>                      Screen Media Films
#
#                                            Release dates   Running time  \
# 0                                                   <NA>     98 minutes
# 1                                                   <NA>  44–45 minutes
# 2                                                   <NA>     83 minutes
# 3      9 May 1987 ( 1987-05-09 ) ( Cannes ) 20 May 19...    111 minutes
# 4                                                   <NA>    106 minutes
# ...                                                  ...            ...
# 81736                                               <NA>     90 minutes
# 81737                                               <NA>     96 minutes
# 81738                                               <NA>         66 min
# 81739                                               <NA>           <NA>
# 81740                                               <NA>     83 minutes
#
#               Country   Language        Budget   Box office
# 0       United States    English   $28 million  $14 million
# 1                <NA>       <NA>          <NA>         <NA>
# 2              Norway  Norwegian          <NA>         <NA>
# 3      United Kingdom    English  $2.8 million         <NA>
# 4        West Germany     German          <NA>         <NA>
# ...               ...        ...           ...          ...
# 81736            <NA>    English          <NA>         <NA>
# 81737         Ireland       <NA>          <NA>         <NA>
# 81738   United States    English          <NA>         <NA>
# 81739            <NA>       <NA>          <NA>         <NA>
# 81740          Canada    English          <NA>         <NA>
#
# [81741 rows x 18 columns]

# %%
len(df["Box office"].dropna())
# Out:
# 18410

# %%
df.to_parquet('./generated/scraped_cmu_movies_infobox.parquet', compression='brotli')

# %%
subset = df.drop('Wikipedia movie ID', axis=1)

df[subset.notna().any(axis=1)]
# Out:
#        Wikipedia movie ID                                      Directed by  \
# 0                  975900                                   John Carpenter
# 1                 3196793                                     Edward Lucas
# 2                28463795                                     Sølve Skagen
# 3                 9363483                                   Donald Cammell
# 4                  261236                               Robert van Ackeren
# ...                   ...                                              ...
# 81735            32468537                                Anton Megerdichev
# 81736            35228177  Sid Bennett Director of Animation - Steve Gomez
# 81737            34980460                                       Ian Palmer
# 81738             9971909                                     Bob Einstein
# 81740            12476867                                    Gavin Wilding
#
#                       Screenplay by                     Story by  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3      Donald Cammell China Cammell                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 81735                          <NA>                         <NA>
# 81736                          <NA>  Charlie Foley Vaibhav Bhatt
# 81737                          <NA>                         <NA>
# 81738                          <NA>                         <NA>
# 81740                          <NA>                         <NA>
#
#                           Based on  \
# 0                             <NA>
# 1                             <NA>
# 2                             <NA>
# 3      Mrs. White by Andrew Klavan
# 4                             <NA>
# ...                            ...
# 81735                         <NA>
# 81736                         <NA>
# 81737                         <NA>
# 81738                         <NA>
# 81740                         <NA>
#
#                                              Produced by  \
# 0                                             Sandy King
# 1                                                   <NA>
# 2                                                   <NA>
# 3      Sue Baden-Powell Cassian Elwes Elliott Kastner...
# 4              Robert van Ackeren Dieter Geissler [ de ]
# ...                                                  ...
# 81735                                               <NA>
# 81736                       Darlow Smithson, Tom Brisley
# 81737                            Teddy Leifer Ian Palmer
# 81738                         Jonathan Haze Tom Smothers
# 81740                                          Mark Reid
#
#                                                 Starring  \
# 0      Ice Cube Natasha Henstridge Jason Statham Pam ...
# 1                                                   <NA>
# 2             Frank Krog Kristin Kajander Anne Krigsvoll
# 3                             David Keith Cathy Moriarty
# 4      Gudrun Landgrebe Mathieu Carrière Hanns Zischl...
# ...                                                  ...
# 81735  Denis Nikiforov Yelena Panova Andrey Panin Vic...
# 81736                                               <NA>
# 81737                                               <NA>
# 81738  Rich Little Herb Voland Bruce Kirby Diahn Will...
# 81740                           Ron Silver Liane Balaban
#
#                  Cinematography           Edited by              Music by  \
# 0                 Gary B. Kibbe  Paul C. Warschilka        John Carpenter
# 1                          <NA>                <NA>                  <NA>
# 2                          <NA>                <NA>                  <NA>
# 3                Larry McConkey      Terry Rawlings  Rick Fenn Nick Mason
# 4                 Jürgen Jürges   Tanja Schmidbauer            Peer Raben
# ...                         ...                 ...                   ...
# 81735                      <NA>                <NA>      Aleksei Shelygin
# 81736                      <NA>                <NA>                  <NA>
# 81737  Michael Doyle Ian Palmer    Ollie Huddleston          Ilan Eshkeri
# 81738                      <NA>                <NA>         Bob Emenegger
# 81740             Mark Dobrescu          Dean Evans       Chris Ainscough
#
#                 Production company                          Distributed by  \
# 0                             <NA>                 Sony Pictures Releasing
# 1      Rocket Science Laboratories                                    <NA>
# 2                             <NA>                                    <NA>
# 3                             <NA>                            Cannon Films
# 4                             <NA>                                    <NA>
# ...                            ...                                     ...
# 81735                         <NA>                                    <NA>
# 81736                         <NA>  Discovery Communications Animal Planet
# 81737                         <NA>                                    <NA>
# 81738                         <NA>                              Fine Films
# 81740                         <NA>                      Screen Media Films
#
#                                            Release dates   Running time  \
# 0                                                   <NA>     98 minutes
# 1                                                   <NA>  44–45 minutes
# 2                                                   <NA>     83 minutes
# 3      9 May 1987 ( 1987-05-09 ) ( Cannes ) 20 May 19...    111 minutes
# 4                                                   <NA>    106 minutes
# ...                                                  ...            ...
# 81735                                               <NA>    132 minutes
# 81736                                               <NA>     90 minutes
# 81737                                               <NA>     96 minutes
# 81738                                               <NA>         66 min
# 81740                                               <NA>     83 minutes
#
#               Country           Language        Budget   Box office
# 0       United States            English   $28 million  $14 million
# 1                <NA>               <NA>          <NA>         <NA>
# 2              Norway          Norwegian          <NA>         <NA>
# 3      United Kingdom            English  $2.8 million         <NA>
# 4        West Germany             German          <NA>         <NA>
# ...               ...                ...           ...          ...
# 81735          Russia  Russian / English          <NA>         <NA>
# 81736            <NA>            English          <NA>         <NA>
# 81737         Ireland               <NA>          <NA>         <NA>
# 81738   United States            English          <NA>         <NA>
# 81740          Canada            English          <NA>         <NA>
#
# [73918 rows x 18 columns]
